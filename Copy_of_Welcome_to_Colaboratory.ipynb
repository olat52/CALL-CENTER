# %% [markdown]
# <a href="https://colab.research.google.com/github/olat52/CALL-CENTER/blob/main/Copy_of_Welcome_to_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Importing Data
call_center=pd.read_excel("Call Center.xlsx")
call_center
# Out:
#      Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3         Unnamed: 4  \
# 0           NaN        NaN         NaN        NaN                NaN
# 1       Call Id      Agent        Date       Time              Topic
# 2        ID0001      Diane  2021-01-01   09:12:58   Contract related
# 3        ID0002      Becky  2021-01-01   09:12:58  Technical Support
# 4        ID0003    Stewart  2021-01-01   09:47:31   Contract related
# ...         ...        ...         ...        ...                ...
# 4997     ID4996        Jim  2021-03-31   16:37:55    Payment related
# 4998     ID4997      Diane  2021-03-31   16:45:07    Payment related
# 4999     ID4998      Diane  2021-03-31   16:53:46    Payment related
# 5000     ID4999        Jim  2021-03-31   17:02:24          Streaming
# 5001     ID5000      Diane  2021-03-31   17:39:50   Contract related
#
#           Unnamed: 5 Unnamed: 6                  Unnamed: 7       Unnamed: 8  \
# 0                NaN        NaN                         NaN              NaN
# 1     Answered (Y/N)   Resolved  Speed of answer in seconds  AvgTalkDuration
# 2                  Y          Y                         109          0:02:23
# 3                  Y          N                          70          0:04:02
# 4                  Y          Y                          10          0:02:11
# ...              ...        ...                         ...              ...
# 4997               Y          Y                          22          0:05:40
# 4998               Y          Y                         100          0:03:16
# 4999               Y          Y                          84          0:01:49
# 5000               Y          Y                          98          0:00:58
# 5001               N          N                         NaN              NaN
#
#                Unnamed: 9
# 0                     NaN
# 1     Satisfaction rating
# 2                       3
# 3                       3
# 4                       3
# ...                   ...
# 4997                    1
# 4998                    3
# 4999                    4
# 5000                    5
# 5001                  NaN
#
# [5002 rows x 10 columns]

# %%
#duplicating data for cleaning
cl=call_center.copy()
cl
# Out:
#      Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3         Unnamed: 4  \
# 0           NaN        NaN         NaN        NaN                NaN
# 1       Call Id      Agent        Date       Time              Topic
# 2        ID0001      Diane  2021-01-01   09:12:58   Contract related
# 3        ID0002      Becky  2021-01-01   09:12:58  Technical Support
# 4        ID0003    Stewart  2021-01-01   09:47:31   Contract related
# ...         ...        ...         ...        ...                ...
# 4997     ID4996        Jim  2021-03-31   16:37:55    Payment related
# 4998     ID4997      Diane  2021-03-31   16:45:07    Payment related
# 4999     ID4998      Diane  2021-03-31   16:53:46    Payment related
# 5000     ID4999        Jim  2021-03-31   17:02:24          Streaming
# 5001     ID5000      Diane  2021-03-31   17:39:50   Contract related
#
#           Unnamed: 5 Unnamed: 6                  Unnamed: 7       Unnamed: 8  \
# 0                NaN        NaN                         NaN              NaN
# 1     Answered (Y/N)   Resolved  Speed of answer in seconds  AvgTalkDuration
# 2                  Y          Y                         109          0:02:23
# 3                  Y          N                          70          0:04:02
# 4                  Y          Y                          10          0:02:11
# ...              ...        ...                         ...              ...
# 4997               Y          Y                          22          0:05:40
# 4998               Y          Y                         100          0:03:16
# 4999               Y          Y                          84          0:01:49
# 5000               Y          Y                          98          0:00:58
# 5001               N          N                         NaN              NaN
#
#                Unnamed: 9
# 0                     NaN
# 1     Satisfaction rating
# 2                       3
# 3                       3
# 4                       3
# ...                   ...
# 4997                    1
# 4998                    3
# 4999                    4
# 5000                    5
# 5001                  NaN
#
# [5002 rows x 10 columns]

# %%
#duplicating data for cleaning
cl=call_center.copy()

cl
# Out:
#      Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3         Unnamed: 4  \
# 0           NaN        NaN         NaN        NaN                NaN
# 1       Call Id      Agent        Date       Time              Topic
# 2        ID0001      Diane  2021-01-01   09:12:58   Contract related
# 3        ID0002      Becky  2021-01-01   09:12:58  Technical Support
# 4        ID0003    Stewart  2021-01-01   09:47:31   Contract related
# ...         ...        ...         ...        ...                ...
# 4997     ID4996        Jim  2021-03-31   16:37:55    Payment related
# 4998     ID4997      Diane  2021-03-31   16:45:07    Payment related
# 4999     ID4998      Diane  2021-03-31   16:53:46    Payment related
# 5000     ID4999        Jim  2021-03-31   17:02:24          Streaming
# 5001     ID5000      Diane  2021-03-31   17:39:50   Contract related
#
#           Unnamed: 5 Unnamed: 6                  Unnamed: 7       Unnamed: 8  \
# 0                NaN        NaN                         NaN              NaN
# 1     Answered (Y/N)   Resolved  Speed of answer in seconds  AvgTalkDuration
# 2                  Y          Y                         109          0:02:23
# 3                  Y          N                          70          0:04:02
# 4                  Y          Y                          10          0:02:11
# ...              ...        ...                         ...              ...
# 4997               Y          Y                          22          0:05:40
# 4998               Y          Y                         100          0:03:16
# 4999               Y          Y                          84          0:01:49
# 5000               Y          Y                          98          0:00:58
# 5001               N          N                         NaN              NaN
#
#                Unnamed: 9
# 0                     NaN
# 1     Satisfaction rating
# 2                       3
# 3                       3
# 4                       3
# ...                   ...
# 4997                    1
# 4998                    3
# 4999                    4
# 5000                    5
# 5001                  NaN
#
# [5002 rows x 10 columns]

# %%
cl
# Out:
# 0         NaN      NaN         NaN       NaN                NaN  \
# 1     Call Id    Agent        Date      Time              Topic
# 2      ID0001    Diane  2021-01-01  09:12:58   Contract related
# 3      ID0002    Becky  2021-01-01  09:12:58  Technical Support
# 4      ID0003  Stewart  2021-01-01  09:47:31   Contract related
# 5      ID0004     Greg  2021-01-01  09:47:31   Contract related
# ...       ...      ...         ...       ...                ...
# 4992   ID4991  Stewart  2021-03-31  13:46:34          Streaming
# 4997   ID4996      Jim  2021-03-31  16:37:55    Payment related
# 4998   ID4997    Diane  2021-03-31  16:45:07    Payment related
# 4999   ID4998    Diane  2021-03-31  16:53:46    Payment related
# 5000   ID4999      Jim  2021-03-31  17:02:24          Streaming
#
# 0                NaN       NaN                         NaN              NaN  \
# 1     Answered (Y/N)  Resolved  Speed of answer in seconds  AvgTalkDuration
# 2                  Y         Y                         109          0:02:23
# 3                  Y         N                          70          0:04:02
# 4                  Y         Y                          10          0:02:11
# 5                  Y         Y                          53          0:00:37
# ...              ...       ...                         ...              ...
# 4992               Y         Y                          73          0:06:26
# 4997               Y         Y                          22          0:05:40
# 4998               Y         Y                         100          0:03:16
# 4999               Y         Y                          84          0:01:49
# 5000               Y         Y                          98          0:00:58
#
# 0                     NaN
# 1     Satisfaction rating
# 2                       3
# 3                       3
# 4                       3
# 5                       2
# ...                   ...
# 4992                    1
# 4997                    1
# 4998                    3
# 4999                    4
# 5000                    5
#
# [4055 rows x 10 columns]

# %%
#making row 1 the table header
cl.columns = cl.iloc[0]
cl = cl[1:].reset_index(drop=True)

cl
# Out:
# 1    Call Id    Agent        Date      Time              Topic Answered (Y/N)  \
# 0     ID0001    Diane  2021-01-01  09:12:58   Contract related              Y
# 1     ID0002    Becky  2021-01-01  09:12:58  Technical Support              Y
# 2     ID0003  Stewart  2021-01-01  09:47:31   Contract related              Y
# 3     ID0004     Greg  2021-01-01  09:47:31   Contract related              Y
# 4     ID0005    Becky  2021-01-01  10:00:29    Payment related              Y
# ...      ...      ...         ...       ...                ...            ...
# 4049  ID4991  Stewart  2021-03-31  13:46:34          Streaming              Y
# 4050  ID4996      Jim  2021-03-31  16:37:55    Payment related              Y
# 4051  ID4997    Diane  2021-03-31  16:45:07    Payment related              Y
# 4052  ID4998    Diane  2021-03-31  16:53:46    Payment related              Y
# 4053  ID4999      Jim  2021-03-31  17:02:24          Streaming              Y
#
# 1    Resolved Speed of answer in seconds AvgTalkDuration Satisfaction rating
# 0           Y                        109         0:02:23                   3
# 1           N                         70         0:04:02                   3
# 2           Y                         10         0:02:11                   3
# 3           Y                         53         0:00:37                   2
# 4           Y                         95         0:01:00                   3
# ...       ...                        ...             ...                 ...
# 4049        Y                         73         0:06:26                   1
# 4050        Y                         22         0:05:40                   1
# 4051        Y                        100         0:03:16                   3
# 4052        Y                         84         0:01:49                   4
# 4053        Y                         98         0:00:58                   5
#
# [4054 rows x 10 columns]

# %%
#displaying all rows
cl = pd.DataFrame(cl)
pd.set_option('display.max_rows', None)
#displaying all rows

#display 10 rows
pd.set_option('display.max_rows', 10)

#fill nan value with 0
cl.fillna(0, inplace=True)
cl
# Out:
# 1    Call Id    Agent        Date      Time              Topic Answered (Y/N)  \
# 0     ID0001    Diane  2021-01-01  09:12:58   Contract related              Y
# 1     ID0002    Becky  2021-01-01  09:12:58  Technical Support              Y
# 2     ID0003  Stewart  2021-01-01  09:47:31   Contract related              Y
# 3     ID0004     Greg  2021-01-01  09:47:31   Contract related              Y
# 4     ID0005    Becky  2021-01-01  10:00:29    Payment related              Y
# ...      ...      ...         ...       ...                ...            ...
# 4049  ID4991  Stewart  2021-03-31  13:46:34          Streaming              Y
# 4050  ID4996      Jim  2021-03-31  16:37:55    Payment related              Y
# 4051  ID4997    Diane  2021-03-31  16:45:07    Payment related              Y
# 4052  ID4998    Diane  2021-03-31  16:53:46    Payment related              Y
# 4053  ID4999      Jim  2021-03-31  17:02:24          Streaming              Y
#
# 1    Resolved Speed of answer in seconds AvgTalkDuration Satisfaction rating
# 0           Y                        109         0:02:23                   3
# 1           N                         70         0:04:02                   3
# 2           Y                         10         0:02:11                   3
# 3           Y                         53         0:00:37                   2
# 4           Y                         95         0:01:00                   3
# ...       ...                        ...             ...                 ...
# 4049        Y                         73         0:06:26                   1
# 4050        Y                         22         0:05:40                   1
# 4051        Y                        100         0:03:16                   3
# 4052        Y                         84         0:01:49                   4
# 4053        Y                         98         0:00:58                   5
#
# [4054 rows x 10 columns]

# %%
#confirming all adjustment done on data
cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4054 entries, 0 to 4053
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Call Id                     4054 non-null   object
#  1   Agent                       4054 non-null   object
#  2   Date                        4054 non-null   object
#  3   Time                        4054 non-null   object
#  4   Topic                       4054 non-null   object
#  5   Answered (Y/N)              4054 non-null   object
#  6   Resolved                    4054 non-null   object
#  7   Speed of answer in seconds  4054 non-null   object
#  8   AvgTalkDuration             4054 non-null   object
#  9   Satisfaction rating         4054 non-null   object
# dtypes: object(10)
# memory usage: 316.8+ KB

# %%
cl["Agent"].unique()
# Out:
# array(['Diane', 'Becky', 'Stewart', 'Greg', 'Jim', 'Joe', 'Martha', 'Dan'],
#       dtype=object)

# %%
cl["Topic"].unique()
# Out:
# array(['Contract related', 'Technical Support', 'Payment related',
#        'Admin Support', 'Streaming'], dtype=object)

# %%
cl["Satisfaction rating"].unique()
# Out:
# array([3, 2, 4, 5, 1], dtype=object)

# %% [markdown]
# Data Analysis:

# %%
#distribution of call volumes over time(date and time)
trend=cl.groupby(['Date','Time'])['Call Id'].count()
pd.DataFrame(trend)
# Out:
#                      Call Id
# Date       Time
# 2021-01-01 09:12:58        2
#            09:47:31        2
#            10:00:29        1
#            10:22:05        2
#            11:13:55        2
# ...                      ...
# 2021-03-31 13:46:34        1
#            16:37:55        1
#            16:45:07        1
#            16:53:46        1
#            17:02:24        1
#
# [2331 rows x 1 columns]

# %%
#the proportion of answered and unresolved calls?
answered= (cl['Answered (Y/N)'] == 'Y').sum()
unresolved=(cl['Resolved']=='N').sum()
answered
#called answered =4054
unresolved
#unresolved is:1354
proportion=(unresolved/answered)*100
rounded=round(proportion,0)
print('The proportion of answered and unresolved call is :%',rounded)
# Out:
# The proportion of answered and unresolved call is :% 10.0

# %% [markdown]
# Having %33 of answered but unresolved calls is unsatisfactory; Agents need improvement so as to ensure customer satisfaction.

# %%
#distribution of call topics
pd.DataFrame(cl.groupby(['Topic'])['Topic'].count().sort_values(ascending=False))
# Out:
#                    Topic
# Topic
# Streaming            847
# Payment related      818
# Technical Support    805
# Admin Support        795
# Contract related     789

# %%
#distribution of customer satisfaction rating
cl.groupby(['Satisfaction rating','Agent'])['Agent'].count().unstack()
# Out:
# Agent                Becky  Dan  Diane  Greg  Jim  Joe  Martha  Stewart
# Satisfaction rating
# 1                       64   49     50    43   57   54      47       53
# 2                       42   47     50    57   54   51      47       48
# 3                      150  166    155   161  157  149     149      131
# 4                      160  143    139   136  157  141     159      145
# 5                      101  118    107   105  111   89     112      100

# %% [markdown]
# Dan has more 5 and 3 star rating records than other agents, Becky took the lead in 4 and 1 star rating
#
# Greg has the highest number of 2 start rating while Diane has more 0 rating than other agents

# %% [markdown]
# **How agents performance varies based on different metrics:**
#
#
# *   Agents engagements
#
# *   Resolved and unresolved cases by agent
#
#
# *   proportion of unresolved calls by agent

# %%
# Agents engagements
agents_entry=cl.groupby(['Agent'])['Agent'].count().sort_values(ascending=False)
pd.DataFrame(agents_entry)
# Out:
#          Agent
# Agent
# Jim        536
# Dan        523
# Becky      517
# Martha     514
# Greg       502
# Diane      501
# Joe        484
# Stewart    477

# %%
#Resolved  and unresolved cases by agent
cl.groupby(['Resolved','Agent'])['Agent'].count().unstack()
# Out:
# Agent     Becky  Dan  Diane  Greg  Jim  Joe  Martha  Stewart
# Resolved
# N            55   52     49    47   51   48      53       53
# Y           462  471    452   455  485  436     461      424

# %% [markdown]
# The table above shows Resolved and unresolved cases of all agents

# %% [markdown]
# *   jim has the highest resolved cases
# *   jim and diane have the highest number of unresolved cases
#
# *   jim picked  more cases than other agents

# %%
#number of answered and unanswered call
cl.groupby(['Answered (Y/N)','Agent'])['Agent'].count().unstack()
# Out:
# Agent           Becky  Dan  Diane  Greg  Jim  Joe  Martha  Stewart
# Answered (Y/N)
# Y                 517  523    501   502  536  484     514      477

# %%
#proportion of unresolved calls by agent
unresolved_counts = cl[cl['Resolved'] == 'N'].groupby('Agent').size()

# Plot a pie chart
plt.pie(unresolved_counts, labels=unresolved_counts.index, autopct='%1.1f%%')
plt.title('Proportion of Unresolved Calls by Agent')
plt.show()

# %% [markdown]
# proportion of unresolved calls by agents apeared not  customer friendly

# %% [markdown]
# Recommendation for improving call centre performance and customer satisfaction:
#
#
#
# *   performance evaluations and setting achievable goals for agents.working critically with customers rating,analizing these ratings so as to know the performance of each agen
#
# *   Recognize and reward high-performing agents to boost morale and motivation within the team.
# *   Educate customers on self-service options and encourage them to use self-help resources,this would reduce the volume of calls handled by agents also would increase effectiveness.
